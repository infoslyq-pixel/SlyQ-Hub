# %% [markdown]
# <a href="https://colab.research.google.com/github/infoslyq-pixel/SlyQ-Hub/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import torch, sys, os
print("Python:", sys.version.split()[0])
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
  prin("CUDAdevice:,"torch.cuda.get_device_name(0))
# Out:
#   File "/tmp/ipython-input-1432878568.py", line 6
#     prin("CUDAdevice:,"torch.cuda.get_device_name(0))
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# :

# %%
import torch, sys, os
print("Python:", sys.version.split()[0])
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device:", torch.cuda.get_device_name(0))
# Out:
# Python: 3.12.12
# Torch: 2.8.0+cu126
# CUDA available: True
# CUDA device: Tesla T4

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128,garbage_collection_threshold:0.6,allocator:default"

# %%
# !pip install -q diffusers accelerate transformers safetensors==0.4.5 einops tqdm moviepy imageio opencv-python decord

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained(
  "stabilityai/stable-video-diffusion-img2vid-xt",
  torch_dtype=torch.float16,
  safety_checker=None
).to("cuda")

print("✅ Pipeline loaded successfully!")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# image_encoder/model.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/391M [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/6.10G [00:00<?, ?B/s]
# Keyword arguments {'safety_checker': None} are not expected by StableVideoDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ✅ Pipeline loaded successfully!

# %%
pip install --upgrade diffusers accelerate transformers xformers pytorchvideo moviepy audiocraft
# Out:
# ...
#   Using cached xformers-0.0.32.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.7/635.7 kB 43.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 78.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...

# %%
from accelerate import Accelerator
accelerator = Accelerator(mixed_precision="fp16")

# %%
pip uninstall -y av pytorchvideo
pip install av==10.0.0 --extra-index-url https://download.pytorch.org/whl/cu121
pip install git+https://github.com/facebookresearch/pytorchvideo.git
# Out:
#   File "/tmp/ipython-input-2024534096.py", line 1
#     pip uninstall -y av pytorchvideo
#         ^
# SyntaxError: invalid syntax

# %%
# !pip uninstall -y av pytorchvideo
# !pip install av==10.0.0 --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install git+https://github.com/facebookresearch/pytorchvideo.git
# Out:
# WARNING: Skipping av as it is not installed.
# WARNING: Skipping pytorchvideo as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 63.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   Cloning https://github.com/facebookresearch/pytorchvideo.git to /tmp/pip-req-build-5zesd3xc
# ...

# %%
# !pip list | grep -E "torch|diffusers|pytorchvideo|audiocraft"
# Out:
# diffusers                                0.35.2
# pytorchvideo                             0.1.5
# torch                                    2.8.0+cu126
# torchao                                  0.10.0
# torchaudio                               2.8.0+cu126
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.23.0+cu126

# %%
pip install opencv-python mediapy decord accelerate==1.11.0
pip install git+https://github.com/huggingface/transformers.git
pip install git+https://github.com/facebookresearch/xformers.git
# Out:
#   File "/tmp/ipython-input-185682342.py", line 1
#     pip install opencv-python mediapy decord accelerate==1.11.0
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install opencv-python mediapy decord accelerate==1.11.0
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install git+https://github.com/facebookresearch/xformers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-ntarh9o2
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-ntarh9o2
#   Resolved https://github.com/huggingface/transformers.git to commit e8a6eb3304033fdd9346fe3b3293309fe50de238
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/facebookresearch/xformers.git to /tmp/pip-req-build-adoq9vc7
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/xformers.git /tmp/pip-req-build-adoq9vc7
#   Resolved https://github.com/facebookresearch/xformers.git to commit e98c69bcf9f2eb4bd583733421fb1dd1f7a6e608
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...
